# %%
import pandas as pd
#load dataset
url="https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv"
df=pd.read_csv(url)

# %%
#define features and target
features=df[['total_bill','size']]
target=df['tip']
features.head()
# Out:
#    total_bill  size
# 0       16.99     2
# 1       10.34     3
# 2       21.01     3
# 3       23.68     2
# 4       24.59     4

# %%
target.head()
# Out:
# 0    1.01
# 1    1.66
# 2    3.50
# 3    3.31
# 4    3.61
# Name: tip, dtype: float64

# %%
# !pip install scikit-learn
from sklearn.model_selection import train_test_split
# Out:
# Requirement already satisfied: scikit-learn in d:\users\hp\anaconda3\lib\site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in d:\users\hp\anaconda3\lib\site-packages (from scikit-learn) (2.3.5)
# Requirement already satisfied: scipy>=1.8.0 in d:\users\hp\anaconda3\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in d:\users\hp\anaconda3\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\users\hp\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(features,target,test_size=0.2,random_state=42)# using random pick data from dataset

# %%
print("training data set:",x_train.shape)
print("testing data set:",x_test.shape)
#divide into 80% and testing 20 %
# Out:
# training data set: (195, 2)
# testing data set: (49, 2)

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in d:\users\hp\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in d:\users\hp\anaconda3\lib\site-packages (from seaborn) (2.3.5)
# Requirement already satisfied: pandas>=1.2 in d:\users\hp\anaconda3\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in d:\users\hp\anaconda3\lib\site-packages (from seaborn) (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in d:\users\hp\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\users\hp\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\users\hp\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\users\hp\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in d:\users\hp\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in d:\users\hp\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\users\hp\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in d:\users\hp\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\users\hp\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\users\hp\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\users\hp\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#visualize relationships
sns.pairplot(df,x_vars=["total_bill","size"],y_vars=`"tip",height=5,aspect=0.8,kind="scatter")
